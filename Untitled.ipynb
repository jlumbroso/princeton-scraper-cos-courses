# %%
import requests
import bs4
import loguru
import urllib.parse
import typing

# %%
# See: https://stackoverflow.com/a/38020041/408734
def uri_validator(x):
    try:
        result = urllib.parse.urlparse(x)
        return all([
            result.scheme,
            result.scheme in ["file", "http", "https"],
            result.netloc,
        ])
    except:
        return False

def fetch_page_as_soup(url, silent_fail=True):
    
    # some light validation
    
    if url is None:
        loguru.logger.error("no URL provided!")
        return
    
    if not uri_validator(url):
        loguru.logger.error("invalid URL provided!")
        return
    
    # make the request
    
    try:
        req = requests.get(url)
    except Exception as exc:
        # if not silent, then reraise exception
        if not silent_fail:
            raise exc
        
        # otherwise just log and return None
        loguru.logger.error("when fetching URL: ", url)
        loguru.logger.exception(exc)
        return
    
    # check request is valid
    
    if not req.ok:
        loguru.logger.warning("status code:", req.status_code)
        return
    
    # return beautiful soup
    
    content = req.content
    
    try:
        soup = bs4.BeautifulSoup(content, "html.parser")
    except Exception as exc:
        # if not silent, then reraise exception
        if not silent_fail:
            raise exc
        
        # otherwise just log and return None
        loguru.logger.error("when parsing content of: ", url)
        loguru.logger.exception(exc)
        return
    
    return soup

# %%
fetch_page_as_soup("https://www.cs.princeton.edu/courses/schedule")

# %%
raw = requests.get("https://www.cs.princeton.edu/courses/schedule").content

# %%
soup = bs4.BeautifulSoup(raw)

# %%
semester_select = soup.find(name="select", attrs={"class": "semester-select"})

# %%
semesters = list(map(
    lambda option_tag: (option_tag["value"], option_tag.text),
    semester_select.find_all("option")))

# %%
semesters

# %%
raw2 = requests.get("https://www.cs.princeton.edu/courses/schedule/fall18").content

# %%
soup2 = bs4.BeautifulSoup(raw2)

# %%
schedule_table = soup2.find(name="table", attrs={"id": "course-schedules"})

# %%
FIELDS = {
    "Num": "course",
    "Name": "title",
    "Professor(s)": "people",
    "Classes": "hours",
    "Room": "room"
}

CosCourseInstance = typing.TypedDict(
    "CosCourseInstance", {
        "course": str,
        "title": str,
        "term": str,
        "people": typing.List[str],
        "hours": str,
        "room": str
    }, total=False)

course_fields_data = [
    {
        "id": i,
        "original": tag.text.strip(),
        "renamed": FIELDS.get(tag.text.strip()),
    }
    for i, tag in enumerate(schedule_table.find("thead").find_all("th"))
]

course_fields_id_to_caption = {
    d["id"]: d["renamed"]
    for d in course_fields_data
}

course_fields_original_to_caption = {
    d["original"]: d["renamed"]
    for d in course_fields_data
}

def process_course_tr(tr_tag):
    td_tags = tr_tag.find_all("td")
    course = {
        course_fields_id_to_caption[i]: td_tag.text
        for i, td_tag in enumerate(td_tags)
    }
    
    course["people"] = course["people"].split(", ")
    
    return course

# %%
CosCourseInstance({})

# %%
course_fields_original_to_caption

# %%
courses = [
    process_course_tr(tr_tag)
    for tr_tag in schedule_table.find("tbody").find_all("tr")
]

# %%
courses

# %%
import sys
sys.path.append("./src")

# %%
import urllib.parse

import princeton_scraper_cos_courses.parsing
import princeton_scraper_cos_courses.helpers

PRINCETON_CS_SCHEDULE_BASE = "https://www.cs.princeton.edu/courses/schedule/"

# Hard-coded fields



def _build_schedule_url(
        term: str,
) -> str:
    url = urllib.parse.urljoin(PRINCETON_CS_SCHEDULE_BASE, term)
    return url

# %%
data = {}

for term in princeton_scraper_cos_courses.parsing.get_all_terms():
    url = _build_schedule_url(term["internal"])
    soup = princeton_scraper_cos_courses.helpers.fetch_page_as_soup(url=url)
    
    schedule_table = soup.find(
        name="table",
        attrs={"id": "course-schedules"}
    )
    courses = [
        princeton_scraper_cos_courses.parsing.parse_cs_course(
            tag=tr_tag,
            term=term,
        )
        for tr_tag in schedule_table.find("tbody").find_all("tr")
    ]
    data[term["internal"]] = courses

# %%
len(data)
# Out:
# 54

# %%
data
# Out:
# {'fall21': [{'course': 'COS 109',
#    'title': 'Computers in Our World',
#    'people': ['B. Kernighan'],
#    'hours': 'MW 1:30-2:50',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 126',
#    'title': 'Computer Science: An Interdisciplinary Approach',
#    'people': ['R. Sedgewick', 'A. Kaplan', 'J. Lumbroso', 'S. Nam Liao'],
#    'hours': 'MW 12:30-1:20',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 217',
#    'title': 'Introduction to Programming Systems',
#    'people': ['S. Rusinkiewicz'],
#    'hours': 'TTh 10:00-10:50',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 226',
#    'title': 'Algorithms and Data Structures',
#    'people': ['K. Wayne', 'D. Leyzberg'],
#    'hours': 'TTh 11:00-12:20',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 231',
#    'title': 'An Integrated, Quantitative Introduction to the Natural Sciences I (See ISC231)',
#    'people': [''],
#    'hours': 'MWF 10:00-10:50',
#    'room': 'TL012',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 232',
#    'title': 'An Integrated, Quantitative Introduction to the Natural Sciences I (See ISC232)',
#    'people': [''],
#    'hours': 'TTh 10:00-10:50',
#    'room': 'IL200',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 302',
#    'title': 'Mathematics for Numerical Computing and Machine Learning',
#    'people': [''],
#    'hours': 'MW 12:30-1:20',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 306',
#    'title': 'Contemporary Logic Design (See ECE206)',
#    'people': [''],
#    'hours': 'TTh 1:30-2:50',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 314',
#    'title': 'Computer and Electronic Music through Programming, Performance, and Composition (See MUS314)',
#    'people': [''],
#    'hours': 'MW 1:30-2:50',
#    'room': 'WC106',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 318',
#    'title': 'Operating Systems',
#    'people': ['J. Singh'],
#    'hours': 'MW 11:00-12:20',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 323',
#    'title': 'Computing and Optimization for the Physical and Social Sciences (See ORF363)',
#    'people': [''],
#    'hours': 'TTh 1:30-2:50',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 324',
#    'title': 'Introduction to Machine Learning',
#    'people': ['S. Arora', 'D. Chen'],
#    'hours': 'MW 1:30-2:50',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 326',
#    'title': 'Functional Programming',
#    'people': ['A. Gupta', 'D. Walker'],
#    'hours': 'MW 11:00-12:20',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 333',
#    'title': 'Advanced Programming Techniques',
#    'people': ['R. Dondero'],
#    'hours': 'TTh 1:30-2:50',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 340',
#    'title': 'Reasoning about Computation',
#    'people': ['R. Raz', 'I. Petras'],
#    'hours': 'MW 3:00-4:20',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 346',
#    'title': 'Introduction to Robotics (See MAE345)',
#    'people': [''],
#    'hours': 'TTh 3:00-4:20',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 360',
#    'title': 'Computational Models of Cognition (See PSY360)',
#    'people': ['T. Griffiths'],
#    'hours': 'MW 11:00-12:20',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 375',
#    'title': 'Computer Architecture and Organization',
#    'people': ['D. August'],
#    'hours': 'TTh 1:30-2:50',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 396',
#    'title': 'Introduction to Quantum Computing (See ECE396)',
#    'people': [''],
#    'hours': 'MW 11:00-12:20',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 397',
#    'title': 'Junior Independent Work (B.S.E. candidates only)',
#    'people': [''],
#    'hours': '',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 429',
#    'title': 'Computer Vision',
#    'people': ['O. Russakovsky'],
#    'hours': 'TTh 3:00-4:20',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 432',
#    'title': 'Information Security',
#    'people': ['A. Narayanan'],
#    'hours': 'TTh 11:00-12:20',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 434',
#    'title': 'Machine Learning Theory (See ECE434)',
#    'people': [''],
#    'hours': 'MWF 9:00-9:50',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 451',
#    'title': 'Computational Geometry',
#    'people': ['B. Chazelle'],
#    'hours': 'MW 1:30-2:50',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 455',
#    'title': 'Introduction to Genomics and Computational Molecular Biology (See QCB455)',
#    'people': ['M. Singh', 'J. Akey', 'C. McWhite'],
#    'hours': 'TTh 11:00-12:20',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 461',
#    'title': 'Computer Networks',
#    'people': ['K. Jamieson'],
#    'hours': 'T 10:00-10:50',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 462',
#    'title': 'Design of Very Large-Scale Integrated (VLSI) Systems (See ECE462)',
#    'people': [''],
#    'hours': 'TTh 11:00-12:20',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 487',
#    'title': 'Theory of Computation',
#    'people': ['G. Kol'],
#    'hours': 'TTh 3:00-4:20',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 497',
#    'title': 'Senior Independent Work (B.S.E. candidates only)',
#    'people': [''],
#    'hours': '',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 512',
#    'title': 'Special Topics in Data and Information Science: Safety-Critical Robotic Systems (See ECE539)',
#    'people': [''],
#    'hours': 'MW 1:30-2:50',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 513',
#    'title': 'Foundations of Probabilistic Modeling',
#    'people': ['A. Dieng'],
#    'hours': 'MW 3:00-4:20',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 516',
#    'title': 'Automated Reasoning about Software',
#    'people': ['Z. Kincaid'],
#    'hours': 'MW 11:00-12:20',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 521',
#    'title': 'Advanced Algorithm Design',
#    'people': ['M. Braverman', 'M. Weinberg'],
#    'hours': 'TTh 1:30-2:50',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 526',
#    'title': 'Advanced Computer Graphics',
#    'people': ['F. Heide'],
#    'hours': 'TTh 3:00-4:20',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 529',
#    'title': 'Advanced Computer Vision',
#    'people': ['J. Deng'],
#    'hours': 'MW 1:30-2:50',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 551',
#    'title': 'Introduction to Genomics and Computational Molecular Biology',
#    'people': ['M. Singh', 'J. Akey', 'C. McWhite'],
#    'hours': 'TTh 11:00-12:20',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 561',
#    'title': 'Advanced Computer Networks',
#    'people': ['R. Netravali'],
#    'hours': 'T 10:00-10:50',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 590',
#    'title': 'Extramural Research Internship',
#    'people': ['B. Raphael'],
#    'hours': '',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 597A',
#    'title': 'Advanced Topics in Computer Science: New Directions in Algorithmic Mechanism Design',
#    'people': ['M. Braverman', 'M. Weinberg'],
#    'hours': 'MW 1:30-2:50',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 597B',
#    'title': 'Advanced Topics in Computer Science: Computational Models of Cognition',
#    'people': ['T. Griffiths'],
#    'hours': 'W 2:00-3:00',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 597C',
#    'title': 'Advanced Topics in Computer Science: Computer Science for Public Policy and Law',
#    'people': ['J. Mayer'],
#    'hours': 'MW 3:00-4:20',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 597D',
#    'title': 'Advanced Topics in Computer Science: Advanced Computational Genomics',
#    'people': ['Y. Pritykin'],
#    'hours': 'W 9:30-12:20',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 597F',
#    'title': 'Advanced Topics in Computer Science: Embodied Language Understanding',
#    'people': ['K. Narasimhan'],
#    'hours': 'MW 11:00-12:20',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}},
#   {'course': 'COS 597I',
#    'title': 'Advanced Topics in Computer Science: Advanced Compilers',
#    'people': ['D. August'],
#    'hours': 'TTh 3:00-4:20',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Fall',
#     'term': 'Fall 2021',
#     'internal': 'fall21',
#     'sortkey': '2021_1'}}],
#  'spring21': [{'course': 'COS 126',
#    'title': 'Computer Science: An Interdisciplinary Approach',
#    'people': ['A. Finkelstein', 'A. Kaplan', 'J. Lumbroso', 'S. Nam Liao'],
#    'hours': '',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Spring',
#     'term': 'Spring 2021',
#     'internal': 'spring21',
#     'sortkey': '2021_0'}},
#   {'course': 'COS 217',
#    'title': 'Introduction to Programming Systems',
#    'people': ['S. Rusinkiewicz', 'D. Gabai', 'C. Moretti'],
#    'hours': '',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Spring',
#     'term': 'Spring 2021',
#     'internal': 'spring21',
#     'sortkey': '2021_0'}},
#   {'course': 'COS 226',
#    'title': 'Algorithms and Data Structures',
#    'people': ['K. Wayne', 'M. Ginsburg', 'D. Leyzberg'],
#    'hours': 'TTh 11:00-12:20',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Spring',
#     'term': 'Spring 2021',
#     'internal': 'spring21',
#     'sortkey': '2021_0'}},
#   {'course': 'COS 233',
#    'title': 'An Integrated, Quantitative Introduction to the Natural Sciences II (See ISC233)',
#    'people': ['O. Troyanskaya',
#     'S. Petry',
#     'G. Scholes',
#     'J. Shaevitz',
#     'M. Wühr'],
#    'hours': 'MWF 10:00-10:50',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Spring',
#     'term': 'Spring 2021',
#     'internal': 'spring21',
#     'sortkey': '2021_0'}},
#   {'course': 'COS 234',
#    'title': 'An Integrated, Quantitative Introduction to the Natural Sciences II (See ISC234)',
#    'people': ['O. Troyanskaya',
#     'S. Petry',
#     'G. Scholes',
#     'J. Shaevitz',
#     'M. Wühr'],
#    'hours': 'TTh 10:00-10:50',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Spring',
#     'term': 'Spring 2021',
#     'internal': 'spring21',
#     'sortkey': '2021_0'}},
#   {'course': 'COS 302',
#    'title': 'Mathematics for Numerical Computing and Machine Learning',
#    'people': ['R. Adams'],
#    'hours': '',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Spring',
#     'term': 'Spring 2021',
#     'internal': 'spring21',
#     'sortkey': '2021_0'}},
#   {'course': 'COS 323',
#    'title': 'Computing and Optimization for the Physical and Social Sciences (See ORF363)',
#    'people': [''],
#    'hours': 'TTh 3:00-4:20',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Spring',
#     'term': 'Spring 2021',
#     'internal': 'spring21',
#     'sortkey': '2021_0'}},
#   {'course': 'COS 324',
#    'title': 'Introduction to Machine Learning',
#    'people': ['E. Hazan', 'T. Griffiths'],
#    'hours': 'MW 1:30-2:50',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Spring',
#     'term': 'Spring 2021',
#     'internal': 'spring21',
#     'sortkey': '2021_0'}},
#   {'course': 'COS 333',
#    'title': 'Advanced Programming Techniques',
#    'people': ['R. Dondero'],
#    'hours': 'TTh 3:00-4:20',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Spring',
#     'term': 'Spring 2021',
#     'internal': 'spring21',
#     'sortkey': '2021_0'}},
#   {'course': 'COS 333I',
#    'title': 'Advanced Programming Techniques (Non-credit)',
#    'people': ['R. Dondero'],
#    'hours': 'TTh 3:00-4:20',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Spring',
#     'term': 'Spring 2021',
#     'internal': 'spring21',
#     'sortkey': '2021_0'}},
#   {'course': 'COS 340',
#    'title': 'Reasoning about Computation',
#    'people': ['R. Raz', 'I. Petras'],
#    'hours': 'MW 3:00-4:20',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Spring',
#     'term': 'Spring 2021',
#     'internal': 'spring21',
#     'sortkey': '2021_0'}},
#   {'course': 'COS 342',
#    'title': 'Introduction to Graph Theory (See MAT375)',
#    'people': [''],
#    'hours': 'TTh 11:00-12:20',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Spring',
#     'term': 'Spring 2021',
#     'internal': 'spring21',
#     'sortkey': '2021_0'}},
#   {'course': 'COS 343',
#    'title': 'Algorithms for Computational Biology',
#    'people': ['B. Raphael'],
#    'hours': 'TTh 11:00-12:20',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Spring',
#     'term': 'Spring 2021',
#     'internal': 'spring21',
#     'sortkey': '2021_0'}},
#   {'course': 'COS 375',
#    'title': 'Computer Architecture and Organization',
#    'people': ['M. Shahrad'],
#    'hours': 'MWF 12:30-1:20',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Spring',
#     'term': 'Spring 2021',
#     'internal': 'spring21',
#     'sortkey': '2021_0'}},
#   {'course': 'COS 398',
#    'title': 'Junior Independent Work (B.S.E. candidates only)',
#    'people': [''],
#    'hours': '',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Spring',
#     'term': 'Spring 2021',
#     'internal': 'spring21',
#     'sortkey': '2021_0'}},
#   {'course': 'COS 401',
#    'title': 'Introduction to Machine Translation (See TRA301)',
#    'people': [''],
#    'hours': 'F 1:30-3:20',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Spring',
#     'term': 'Spring 2021',
#     'internal': 'spring21',
#     'sortkey': '2021_0'}},
#   {'course': 'COS 415',
#    'title': 'Can We Build Anti-Racist Technologies? (See SOC414)',
#    'people': [''],
#    'hours': 'TTh 3:00-4:20',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Spring',
#     'term': 'Spring 2021',
#     'internal': 'spring21',
#     'sortkey': '2021_0'}},
#   {'course': 'COS 418',
#    'title': 'Distributed Systems',
#    'people': ['W. Lloyd'],
#    'hours': 'MW 10:00-10:50',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Spring',
#     'term': 'Spring 2021',
#     'internal': 'spring21',
#     'sortkey': '2021_0'}},
#   {'course': 'COS 423',
#    'title': 'Theory of Algorithms',
#    'people': ['R. Tarjan'],
#    'hours': 'MW 11:00-12:20',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Spring',
#     'term': 'Spring 2021',
#     'internal': 'spring21',
#     'sortkey': '2021_0'}},
#   {'course': 'COS 424',
#    'title': 'Fundamentals of Machine Learning',
#    'people': ['B. Engelhardt', 'X. Li'],
#    'hours': '',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Spring',
#     'term': 'Spring 2021',
#     'internal': 'spring21',
#     'sortkey': '2021_0'}},
#   {'course': 'COS 426',
#    'title': 'Computer Graphics',
#    'people': ['F. Heide'],
#    'hours': 'TTh 3:00-4:20',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Spring',
#     'term': 'Spring 2021',
#     'internal': 'spring21',
#     'sortkey': '2021_0'}},
#   {'course': 'COS 432',
#    'title': 'Information Security',
#    'people': ['P. Mittal'],
#    'hours': 'TTh 11:00-12:20',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Spring',
#     'term': 'Spring 2021',
#     'internal': 'spring21',
#     'sortkey': '2021_0'}},
#   {'course': 'COS 445',
#    'title': 'Economics and Computing',
#    'people': ['M. Weinberg'],
#    'hours': 'TTh 1:30-2:50',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Spring',
#     'term': 'Spring 2021',
#     'internal': 'spring21',
#     'sortkey': '2021_0'}},
#   {'course': 'COS 448',
#    'title': 'Innovating Across Technology, Business, and Marketplaces',
#    'people': ['J. Singh', 'R. Fish'],
#    'hours': 'MW 11:00-12:20',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Spring',
#     'term': 'Spring 2021',
#     'internal': 'spring21',
#     'sortkey': '2021_0'}},
#   {'course': 'COS 475',
#    'title': 'Computer Architecture (See ELE475)',
#    'people': [''],
#    'hours': 'F 7:30-10:20',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Spring',
#     'term': 'Spring 2021',
#     'internal': 'spring21',
#     'sortkey': '2021_0'}},
#   {'course': 'COS 484',
#    'title': 'Natural Language Processing',
#    'people': ['D. Chen', 'K. Narasimhan'],
#    'hours': 'MW 1:30-2:50',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Spring',
#     'term': 'Spring 2021',
#     'internal': 'spring21',
#     'sortkey': '2021_0'}},
#   {'course': 'COS 488',
#    'title': 'Introduction to Analytic Combinatorics',
#    'people': ['R. Sedgewick', 'J. Lumbroso'],
#    'hours': '',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Spring',
#     'term': 'Spring 2021',
#     'internal': 'spring21',
#     'sortkey': '2021_0'}},
#   {'course': 'COS 498',
#    'title': 'Senior Independent Work (B.S.E. candidates only)',
#    'people': [''],
#    'hours': '',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Spring',
#     'term': 'Spring 2021',
#     'internal': 'spring21',
#     'sortkey': '2021_0'}},
#   {'course': 'COS 510',
#    'title': 'Programming Languages',
#    'people': ['A. Appel'],
#    'hours': 'MW 3:00-4:20',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Spring',
#     'term': 'Spring 2021',
#     'internal': 'spring21',
#     'sortkey': '2021_0'}},
#   {'course': 'COS 512',
#    'title': 'Special Topics in Data and Information Science: Optimization for Machine Learning (See ELE539)',
#    'people': [''],
#    'hours': 'MW 9:30-10:50',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Spring',
#     'term': 'Spring 2021',
#     'internal': 'spring21',
#     'sortkey': '2021_0'}},
#   {'course': 'COS 524',
#    'title': 'Fundamentals of Machine Learning',
#    'people': ['B. Engelhardt', 'X. Li'],
#    'hours': '',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Spring',
#     'term': 'Spring 2021',
#     'internal': 'spring21',
#     'sortkey': '2021_0'}},
#   {'course': 'COS 529',
#    'title': 'Advanced Computer Vision',
#    'people': ['J. Deng'],
#    'hours': 'TTh 1:30-2:50',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Spring',
#     'term': 'Spring 2021',
#     'internal': 'spring21',
#     'sortkey': '2021_0'}},
#   {'course': 'COS 533',
#    'title': 'Advanced Cryptography',
#    'people': ['M. Zhandry'],
#    'hours': 'TTh 1:30-2:50',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Spring',
#     'term': 'Spring 2021',
#     'internal': 'spring21',
#     'sortkey': '2021_0'}},
#   {'course': 'COS 534',
#    'title': 'Fairness in Machine Learning',
#    'people': ['A. Narayanan'],
#    'hours': 'TTh 11:00-12:20',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Spring',
#     'term': 'Spring 2021',
#     'internal': 'spring21',
#     'sortkey': '2021_0'}},
#   {'course': 'COS 563',
#    'title': 'Wireless Networks',
#    'people': ['K. Jamieson', 'Y. Xie'],
#    'hours': 'TTh 3:00-4:20',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Spring',
#     'term': 'Spring 2021',
#     'internal': 'spring21',
#     'sortkey': '2021_0'}},
#   {'course': 'COS 584',
#    'title': 'Advanced Natural Language Processing',
#    'people': ['D. Chen', 'K. Narasimhan'],
#    'hours': 'MW 1:30-2:50',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Spring',
#     'term': 'Spring 2021',
#     'internal': 'spring21',
#     'sortkey': '2021_0'}},
#   {'course': 'COS 590',
#    'title': 'Extramural Research Internship',
#    'people': ['B. Raphael'],
#    'hours': '',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Spring',
#     'term': 'Spring 2021',
#     'internal': 'spring21',
#     'sortkey': '2021_0'}},
#   {'course': 'COS 598A',
#    'title': 'Advanced Topics in Computer Science: Operating System Trade-Offs: Performance, Extensibility, and Security',
#    'people': ['A. Levy'],
#    'hours': 'TTh 1:30-2:50',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Spring',
#     'term': 'Spring 2021',
#     'internal': 'spring21',
#     'sortkey': '2021_0'}},
#   {'course': 'COS 598B',
#    'title': 'Advanced Topics in Computer Science: Mathematical Understanding of Deep Learning',
#    'people': ['S. Arora'],
#    'hours': 'MW 3:00-4:20',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Spring',
#     'term': 'Spring 2021',
#     'internal': 'spring21',
#     'sortkey': '2021_0'}},
#   {'course': 'COS 598D',
#    'title': 'Advanced Topics in Computer Science: Systems and Machine Learning',
#    'people': ['K. Li'],
#    'hours': 'TTh 9:30-10:50',
#    'room': '',
#    'term': {'year': 2021,
#     'period': 'Spring',
#     'term': 'Spring 2021',
#     'internal': 'spring21',
#     'sortkey': '2021_0'}}],
#  'fall20': [{'course': 'COS 109',
#    'title': 'Computers in Our World',
#    'people': ['B. Kernighan'],
#    'hours': 'MW 1:30-2:50',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Fall',
#     'term': 'Fall 2020',
#     'internal': 'fall20',
#     'sortkey': '2020_1'}},
#   {'course': 'COS 126',
#    'title': 'Computer Science: An Interdisciplinary Approach',
#    'people': ['D. August'],
#    'hours': '',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Fall',
#     'term': 'Fall 2020',
#     'internal': 'fall20',
#     'sortkey': '2020_1'}},
#   {'course': 'COS 217',
#    'title': 'Introduction to Programming Systems',
#    'people': ['C. Moretti'],
#    'hours': '',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Fall',
#     'term': 'Fall 2020',
#     'internal': 'fall20',
#     'sortkey': '2020_1'}},
#   {'course': 'COS 226',
#    'title': 'Algorithms and Data Structures',
#    'people': ['K. Wayne'],
#    'hours': 'TTh 11:00-12:20',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Fall',
#     'term': 'Fall 2020',
#     'internal': 'fall20',
#     'sortkey': '2020_1'}},
#   {'course': 'COS 231',
#    'title': 'An Integrated, Quantitative Introduction to the Natural Sciences I (See ISC231)',
#    'people': [''],
#    'hours': 'MWF 10:00-10:50',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Fall',
#     'term': 'Fall 2020',
#     'internal': 'fall20',
#     'sortkey': '2020_1'}},
#   {'course': 'COS 232',
#    'title': 'An Integrated, Quantitative Introduction to the Natural Sciences I (See ISC232)',
#    'people': [''],
#    'hours': 'TTh 10:00-10:50',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Fall',
#     'term': 'Fall 2020',
#     'internal': 'fall20',
#     'sortkey': '2020_1'}},
#   {'course': 'COS 302',
#    'title': 'Mathematics for Numerical Computing and Machine Learning',
#    'people': ['S. Rusinkiewicz'],
#    'hours': 'MW 12:30-1:20',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Fall',
#     'term': 'Fall 2020',
#     'internal': 'fall20',
#     'sortkey': '2020_1'}},
#   {'course': 'COS 306',
#    'title': 'Contemporary Logic Design (See ELE206)',
#    'people': [''],
#    'hours': 'TTh 1:30-2:50',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Fall',
#     'term': 'Fall 2020',
#     'internal': 'fall20',
#     'sortkey': '2020_1'}},
#   {'course': 'COS 316',
#    'title': 'Principles of Computer System Design',
#    'people': ['A. Levy', 'W. Lloyd'],
#    'hours': 'MW 1:30-2:20',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Fall',
#     'term': 'Fall 2020',
#     'internal': 'fall20',
#     'sortkey': '2020_1'}},
#   {'course': 'COS 318',
#    'title': 'Operating Systems',
#    'people': ['J. Singh'],
#    'hours': 'MW 11:00-12:20',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Fall',
#     'term': 'Fall 2020',
#     'internal': 'fall20',
#     'sortkey': '2020_1'}},
#   {'course': 'COS 323',
#    'title': 'Computing and Optimization for the Physical and Social Sciences (See ORF363)',
#    'people': [''],
#    'hours': 'TTh 1:30-2:50',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Fall',
#     'term': 'Fall 2020',
#     'internal': 'fall20',
#     'sortkey': '2020_1'}},
#   {'course': 'COS 324',
#    'title': 'Introduction to Machine Learning',
#    'people': ['S. Arora'],
#    'hours': 'TTh 3:00-4:20',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Fall',
#     'term': 'Fall 2020',
#     'internal': 'fall20',
#     'sortkey': '2020_1'}},
#   {'course': 'COS 326',
#    'title': 'Functional Programming',
#    'people': ['A. Appel', 'D. Walker'],
#    'hours': '',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Fall',
#     'term': 'Fall 2020',
#     'internal': 'fall20',
#     'sortkey': '2020_1'}},
#   {'course': 'COS 333',
#    'title': 'Advanced Programming Techniques',
#    'people': ['R. Dondero'],
#    'hours': 'TTh 1:30-2:50',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Fall',
#     'term': 'Fall 2020',
#     'internal': 'fall20',
#     'sortkey': '2020_1'}},
#   {'course': 'COS 333I',
#    'title': 'Advanced Programming Techniques (Non-credit)',
#    'people': ['R. Dondero'],
#    'hours': 'TTh 1:30-2:50',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Fall',
#     'term': 'Fall 2020',
#     'internal': 'fall20',
#     'sortkey': '2020_1'}},
#   {'course': 'COS 340',
#    'title': 'Reasoning about Computation',
#    'people': ['R. Raz', 'I. Petras'],
#    'hours': 'MW 3:00-4:20',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Fall',
#     'term': 'Fall 2020',
#     'internal': 'fall20',
#     'sortkey': '2020_1'}},
#   {'course': 'COS 396',
#    'title': 'Introduction to Quantum Computing (See ELE396)',
#    'people': [''],
#    'hours': 'MW 11:00-12:20',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Fall',
#     'term': 'Fall 2020',
#     'internal': 'fall20',
#     'sortkey': '2020_1'}},
#   {'course': 'COS 397',
#    'title': 'Junior Independent Work (B.S.E. candidates only)',
#    'people': [''],
#    'hours': '',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Fall',
#     'term': 'Fall 2020',
#     'internal': 'fall20',
#     'sortkey': '2020_1'}},
#   {'course': 'COS 409',
#    'title': 'Critical Approaches to Human Computer Interaction (See SOC409)',
#    'people': [''],
#    'hours': 'T 1:30-4:20',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Fall',
#     'term': 'Fall 2020',
#     'internal': 'fall20',
#     'sortkey': '2020_1'}},
#   {'course': 'COS 429',
#    'title': 'Computer Vision',
#    'people': ['O. Russakovsky', 'J. Deng'],
#    'hours': '',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Fall',
#     'term': 'Fall 2020',
#     'internal': 'fall20',
#     'sortkey': '2020_1'}},
#   {'course': 'COS 433',
#    'title': 'Cryptography',
#    'people': ['M. Zhandry'],
#    'hours': 'TTh 11:00-12:20',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Fall',
#     'term': 'Fall 2020',
#     'internal': 'fall20',
#     'sortkey': '2020_1'}},
#   {'course': 'COS 454',
#    'title': 'Probabilistic Models of Cognition (See PSY454)',
#    'people': ['T. Griffiths'],
#    'hours': 'TTh 11:00-12:20',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Fall',
#     'term': 'Fall 2020',
#     'internal': 'fall20',
#     'sortkey': '2020_1'}},
#   {'course': 'COS 455',
#    'title': 'Introduction to Genomics and Computational Molecular Biology (See QCB455)',
#    'people': ['M. Singh', 'J. Akey'],
#    'hours': '',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Fall',
#     'term': 'Fall 2020',
#     'internal': 'fall20',
#     'sortkey': '2020_1'}},
#   {'course': 'COS 461',
#    'title': 'Computer Networks',
#    'people': ['K. Jamieson', 'J. Rexford'],
#    'hours': 'TTh 10:00-10:50',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Fall',
#     'term': 'Fall 2020',
#     'internal': 'fall20',
#     'sortkey': '2020_1'}},
#   {'course': 'COS 462',
#    'title': 'Design of Very Large-Scale Integrated (VLSI) Systems (See ELE462)',
#    'people': [''],
#    'hours': 'TTh 11:00-12:20',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Fall',
#     'term': 'Fall 2020',
#     'internal': 'fall20',
#     'sortkey': '2020_1'}},
#   {'course': 'COS 497',
#    'title': 'Senior Independent Work (B.S.E. candidates only)',
#    'people': [''],
#    'hours': '',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Fall',
#     'term': 'Fall 2020',
#     'internal': 'fall20',
#     'sortkey': '2020_1'}},
#   {'course': 'COS 516',
#    'title': 'Automated Reasoning about Software',
#    'people': ['A. Gupta'],
#    'hours': 'MW 11:00-12:20',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Fall',
#     'term': 'Fall 2020',
#     'internal': 'fall20',
#     'sortkey': '2020_1'}},
#   {'course': 'COS 521',
#    'title': 'Advanced Algorithm Design',
#    'people': ['M. Weinberg'],
#    'hours': 'TTh 1:30-2:50',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Fall',
#     'term': 'Fall 2020',
#     'internal': 'fall20',
#     'sortkey': '2020_1'}},
#   {'course': 'COS 528',
#    'title': 'Data Structures and Graph Algorithms',
#    'people': ['R. Tarjan'],
#    'hours': 'M 1:30-4:20',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Fall',
#     'term': 'Fall 2020',
#     'internal': 'fall20',
#     'sortkey': '2020_1'}},
#   {'course': 'COS 551',
#    'title': 'Introduction to Genomics and Computational Molecular Biology',
#    'people': ['M. Singh', 'J. Akey'],
#    'hours': '',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Fall',
#     'term': 'Fall 2020',
#     'internal': 'fall20',
#     'sortkey': '2020_1'}},
#   {'course': 'COS 561',
#    'title': 'Advanced Computer Networks',
#    'people': ['K. Jamieson', 'J. Rexford'],
#    'hours': 'TTh 10:00-10:50',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Fall',
#     'term': 'Fall 2020',
#     'internal': 'fall20',
#     'sortkey': '2020_1'}},
#   {'course': 'COS 590',
#    'title': 'Extramural Research Internship',
#    'people': ['B. Raphael'],
#    'hours': '',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Fall',
#     'term': 'Fall 2020',
#     'internal': 'fall20',
#     'sortkey': '2020_1'}},
#   {'course': 'COS 597A',
#    'title': 'Advanced Topics in Computer Science: Imaging the Invisible',
#    'people': ['F. Heide'],
#    'hours': 'TTh 3:00-4:20',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Fall',
#     'term': 'Fall 2020',
#     'internal': 'fall20',
#     'sortkey': '2020_1'}},
#   {'course': 'COS 597D',
#    'title': 'Advanced Topics in Computer Science: Computational Control Theory',
#    'people': ['E. Hazan'],
#    'hours': 'W 1:30-4:20',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Fall',
#     'term': 'Fall 2020',
#     'internal': 'fall20',
#     'sortkey': '2020_1'}},
#   {'course': 'COS 597E',
#    'title': 'Advanced Topics in Computer Science: Limits to Prediction',
#    'people': ['A. Narayanan', 'M. Salganik'],
#    'hours': 'TTh 11:00-12:20',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Fall',
#     'term': 'Fall 2020',
#     'internal': 'fall20',
#     'sortkey': '2020_1'}},
#   {'course': 'COS 597F',
#    'title': 'Advanced Topics in Computer Science: Computational Biology of Single Cells',
#    'people': ['B. Raphael'],
#    'hours': 'F 10:00-12:20',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Fall',
#     'term': 'Fall 2020',
#     'internal': 'fall20',
#     'sortkey': '2020_1'}},
#   {'course': 'COS 597L',
#    'title': 'Special Topics in Data and Information Science: Safety-Critical Robotic Systems (See ELE539)',
#    'people': [''],
#    'hours': 'MW 1:30-2:50',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Fall',
#     'term': 'Fall 2020',
#     'internal': 'fall20',
#     'sortkey': '2020_1'}}],
#  'spring20': [{'course': 'COS 126',
#    'title': 'Computer Science: An Interdisciplinary Approach',
#    'people': ['R. Sedgewick', 'A. Kaplan', 'D. Leyzberg', 'S. Nam Liao'],
#    'hours': 'TTh 12:30-1:20',
#    'room': 'MC50',
#    'term': {'year': 2020,
#     'period': 'Spring',
#     'term': 'Spring 2020',
#     'internal': 'spring20',
#     'sortkey': '2020_0'}},
#   {'course': 'COS 217',
#    'title': 'Introduction to Programming Systems',
#    'people': ['C. Moretti'],
#    'hours': 'MW 10:00-10:50',
#    'room': 'FC101',
#    'term': {'year': 2020,
#     'period': 'Spring',
#     'term': 'Spring 2020',
#     'internal': 'spring20',
#     'sortkey': '2020_0'}},
#   {'course': 'COS 226',
#    'title': 'Algorithms and Data Structures',
#    'people': ['K. Wayne'],
#    'hours': 'TTh 11:00-12:20',
#    'room': 'FC101',
#    'term': {'year': 2020,
#     'period': 'Spring',
#     'term': 'Spring 2020',
#     'internal': 'spring20',
#     'sortkey': '2020_0'}},
#   {'course': 'COS 233',
#    'title': 'An Integrated, Quantitative Introduction to the Natural Sciences II (See ISC233)',
#    'people': ['O. Troyanskaya', 'J. Shaevitz', 'M. Wühr'],
#    'hours': 'MWF 10:00-10:50',
#    'room': 'IL101',
#    'term': {'year': 2020,
#     'period': 'Spring',
#     'term': 'Spring 2020',
#     'internal': 'spring20',
#     'sortkey': '2020_0'}},
#   {'course': 'COS 234',
#    'title': 'An Integrated, Quantitative Introduction to the Natural Sciences II (See ISC234)',
#    'people': ['O. Troyanskaya', 'J. Shaevitz', 'M. Wühr'],
#    'hours': 'TTh 10:00-10:50',
#    'room': 'IL101',
#    'term': {'year': 2020,
#     'period': 'Spring',
#     'term': 'Spring 2020',
#     'internal': 'spring20',
#     'sortkey': '2020_0'}},
#   {'course': 'COS 302',
#    'title': 'Mathematics for Numerical Computing and Machine Learning',
#    'people': ['R. Adams'],
#    'hours': 'MW 12:30-1:20',
#    'room': 'FC101',
#    'term': {'year': 2020,
#     'period': 'Spring',
#     'term': 'Spring 2020',
#     'internal': 'spring20',
#     'sortkey': '2020_0'}},
#   {'course': 'COS 320',
#    'title': 'Compiling Techniques',
#    'people': ['Z. Kincaid'],
#    'hours': 'TTh 1:30-2:50',
#    'room': 'FC111',
#    'term': {'year': 2020,
#     'period': 'Spring',
#     'term': 'Spring 2020',
#     'internal': 'spring20',
#     'sortkey': '2020_0'}},
#   {'course': 'COS 324',
#    'title': 'Introduction to Machine Learning',
#    'people': ['Y. Singer'],
#    'hours': 'MW 1:30-2:50',
#    'room': 'CS104',
#    'term': {'year': 2020,
#     'period': 'Spring',
#     'term': 'Spring 2020',
#     'internal': 'spring20',
#     'sortkey': '2020_0'}},
#   {'course': 'COS 333',
#    'title': 'Advanced Programming Techniques',
#    'people': ['R. Dondero'],
#    'hours': 'TTh 3:00-4:20',
#    'room': 'FC006',
#    'term': {'year': 2020,
#     'period': 'Spring',
#     'term': 'Spring 2020',
#     'internal': 'spring20',
#     'sortkey': '2020_0'}},
#   {'course': 'COS 340',
#    'title': 'Reasoning about Computation',
#    'people': ['R. Raz', 'I. Petras'],
#    'hours': 'MW 3:00-4:20',
#    'room': 'CS104',
#    'term': {'year': 2020,
#     'period': 'Spring',
#     'term': 'Spring 2020',
#     'internal': 'spring20',
#     'sortkey': '2020_0'}},
#   {'course': 'COS 342',
#    'title': 'Introduction to Graph Theory (See MAT375)',
#    'people': ['P. Seymour'],
#    'hours': 'TTh 11:00-12:20',
#    'room': 'FH214',
#    'term': {'year': 2020,
#     'period': 'Spring',
#     'term': 'Spring 2020',
#     'internal': 'spring20',
#     'sortkey': '2020_0'}},
#   {'course': 'COS 343',
#    'title': 'Algorithms for Computational Biology',
#    'people': ['B. Raphael'],
#    'hours': 'TTh 11:00-12:20',
#    'room': 'FC110',
#    'term': {'year': 2020,
#     'period': 'Spring',
#     'term': 'Spring 2020',
#     'internal': 'spring20',
#     'sortkey': '2020_0'}},
#   {'course': 'COS 375',
#    'title': 'Computer Architecture and Organization',
#    'people': ['D. August'],
#    'hours': 'MW 3:00-4:20',
#    'room': 'jrrbA17',
#    'term': {'year': 2020,
#     'period': 'Spring',
#     'term': 'Spring 2020',
#     'internal': 'spring20',
#     'sortkey': '2020_0'}},
#   {'course': 'COS 398',
#    'title': 'Junior Independent Work (B.S.E. candidates only)',
#    'people': [''],
#    'hours': '',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Spring',
#     'term': 'Spring 2020',
#     'internal': 'spring20',
#     'sortkey': '2020_0'}},
#   {'course': 'COS 401',
#    'title': 'Introduction to Machine Translation (See TRA301)',
#    'people': ['S. Bangalore'],
#    'hours': 'F 1:30-4:20',
#    'room': 'GN0-S-9',
#    'term': {'year': 2020,
#     'period': 'Spring',
#     'term': 'Spring 2020',
#     'internal': 'spring20',
#     'sortkey': '2020_0'}},
#   {'course': 'COS 423',
#    'title': 'Theory of Algorithms',
#    'people': ['R. Tarjan'],
#    'hours': 'MW 11:00-12:20',
#    'room': 'FC009',
#    'term': {'year': 2020,
#     'period': 'Spring',
#     'term': 'Spring 2020',
#     'internal': 'spring20',
#     'sortkey': '2020_0'}},
#   {'course': 'COS 426',
#    'title': 'Computer Graphics',
#    'people': ['F. Heide'],
#    'hours': 'TTh 3:00-4:20',
#    'room': 'CS104',
#    'term': {'year': 2020,
#     'period': 'Spring',
#     'term': 'Spring 2020',
#     'internal': 'spring20',
#     'sortkey': '2020_0'}},
#   {'course': 'COS 433',
#    'title': 'Cryptography',
#    'people': ['M. Zhandry'],
#    'hours': 'TTh 11:00-12:20',
#    'room': 'FC008',
#    'term': {'year': 2020,
#     'period': 'Spring',
#     'term': 'Spring 2020',
#     'internal': 'spring20',
#     'sortkey': '2020_0'}},
#   {'course': 'COS 445',
#    'title': 'Economics and Computing',
#    'people': ['M. Weinberg'],
#    'hours': 'TTh 1:30-2:50',
#    'room': 'FC101',
#    'term': {'year': 2020,
#     'period': 'Spring',
#     'term': 'Spring 2020',
#     'internal': 'spring20',
#     'sortkey': '2020_0'}},
#   {'course': 'COS 448',
#    'title': 'Innovating Across Technology, Business, and Marketplaces',
#    'people': ['J. Singh', 'R. Fish'],
#    'hours': 'MW 11:00-12:20',
#    'room': 'FC008',
#    'term': {'year': 2020,
#     'period': 'Spring',
#     'term': 'Spring 2020',
#     'internal': 'spring20',
#     'sortkey': '2020_0'}},
#   {'course': 'COS 461',
#    'title': 'Computer Networks',
#    'people': ['M. Freedman'],
#    'hours': 'MW 1:30-2:50',
#    'room': 'RH002',
#    'term': {'year': 2020,
#     'period': 'Spring',
#     'term': 'Spring 2020',
#     'internal': 'spring20',
#     'sortkey': '2020_0'}},
#   {'course': 'COS 485',
#    'title': 'Neural Networks:  Theory and Applications',
#    'people': ['S. Seung'],
#    'hours': 'TTh 3:00-4:20',
#    'room': 'MC46',
#    'term': {'year': 2020,
#     'period': 'Spring',
#     'term': 'Spring 2020',
#     'internal': 'spring20',
#     'sortkey': '2020_0'}},
#   {'course': 'COS 488',
#    'title': 'Introduction to Analytic Combinatorics',
#    'people': ['R. Sedgewick'],
#    'hours': 'MW 12:30-1:20',
#    'room': 'CS302',
#    'term': {'year': 2020,
#     'period': 'Spring',
#     'term': 'Spring 2020',
#     'internal': 'spring20',
#     'sortkey': '2020_0'}},
#   {'course': 'COS 498',
#    'title': 'Senior Independent Work (B.S.E. candidates only)',
#    'people': [''],
#    'hours': '',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Spring',
#     'term': 'Spring 2020',
#     'internal': 'spring20',
#     'sortkey': '2020_0'}},
#   {'course': 'COS 510',
#    'title': 'Programming Languages',
#    'people': ['A. Appel'],
#    'hours': 'MW 3:00-4:20',
#    'room': 'FC109',
#    'term': {'year': 2020,
#     'period': 'Spring',
#     'term': 'Spring 2020',
#     'internal': 'spring20',
#     'sortkey': '2020_0'}},
#   {'course': 'COS 522',
#    'title': 'Computational Complexity',
#    'people': ['G. Kol'],
#    'hours': 'TTh 3:00-4:20',
#    'room': 'GN0-S-6',
#    'term': {'year': 2020,
#     'period': 'Spring',
#     'term': 'Spring 2020',
#     'internal': 'spring20',
#     'sortkey': '2020_0'}},
#   {'course': 'COS 529',
#    'title': 'Advanced Computer Vision',
#    'people': ['J. Deng'],
#    'hours': 'F 1:00-3:50',
#    'room': 'FC004',
#    'term': {'year': 2020,
#     'period': 'Spring',
#     'term': 'Spring 2020',
#     'internal': 'spring20',
#     'sortkey': '2020_0'}},
#   {'course': 'COS 586',
#    'title': 'Topics in STEP: Technology Policy and Law (See WWS586F)',
#    'people': ['J. Mayer'],
#    'hours': 'T 1:30-4:30',
#    'room': 'RH035',
#    'term': {'year': 2020,
#     'period': 'Spring',
#     'term': 'Spring 2020',
#     'internal': 'spring20',
#     'sortkey': '2020_0'}},
#   {'course': 'COS 590',
#    'title': 'Extramural Research Internship',
#    'people': ['B. Raphael'],
#    'hours': '',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Spring',
#     'term': 'Spring 2020',
#     'internal': 'spring20',
#     'sortkey': '2020_0'}},
#   {'course': 'COS 598A',
#    'title': 'Advanced Topics in Computer Science: Advanced Topics in Complexity Theory',
#    'people': ['Z. Dvir'],
#    'hours': 'MW 1:30-2:50',
#    'room': 'CS402',
#    'term': {'year': 2020,
#     'period': 'Spring',
#     'term': 'Spring 2020',
#     'internal': 'spring20',
#     'sortkey': '2020_0'}},
#   {'course': 'COS 598B',
#    'title': 'Advanced Topics in Computer Science: Advances in Automated Reasoning',
#    'people': ['A. Gupta'],
#    'hours': 'MW 11:00-12:20',
#    'room': 'CS302',
#    'term': {'year': 2020,
#     'period': 'Spring',
#     'term': 'Spring 2020',
#     'internal': 'spring20',
#     'sortkey': '2020_0'}},
#   {'course': 'COS 598C',
#    'title': 'Advanced Topics in Computer Science: Deep Learning for Natural Language Processing',
#    'people': ['D. Chen'],
#    'hours': 'TTh 1:30-2:50',
#    'room': 'EQA224',
#    'term': {'year': 2020,
#     'period': 'Spring',
#     'term': 'Spring 2020',
#     'internal': 'spring20',
#     'sortkey': '2020_0'}},
#   {'course': 'COS 598D',
#    'title': 'Advanced Topics in Computer Science: Systems and Machine Learning',
#    'people': ['K. Li'],
#    'hours': 'MW 1:30-2:50',
#    'room': 'CS302',
#    'term': {'year': 2020,
#     'period': 'Spring',
#     'term': 'Spring 2020',
#     'internal': 'spring20',
#     'sortkey': '2020_0'}},
#   {'course': 'COS 90',
#    'title': 'Topics in Machine Learning',
#    'people': [''],
#    'hours': '',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Spring',
#     'term': 'Spring 2020',
#     'internal': 'spring20',
#     'sortkey': '2020_0'}},
#   {'course': 'COS 983',
#    'title': 'Senior Departmental Exam',
#    'people': [''],
#    'hours': '',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Spring',
#     'term': 'Spring 2020',
#     'internal': 'spring20',
#     'sortkey': '2020_0'}},
#   {'course': 'COS 984',
#    'title': 'Senior Thesis',
#    'people': [''],
#    'hours': '',
#    'room': '',
#    'term': {'year': 2020,
#     'period': 'Spring',
#     'term': 'Spring 2020',
#     'internal': 'spring20',
#     'sortkey': '2020_0'}}],
#  'fall19': [{'course': 'COS 109',
#    'title': 'Computers in Our World',
#    'people': ['B. Kernighan'],
#    'hours': 'MW 1:30-2:50',
#    'room': 'LL138',
#    'term': {'year': 2019,
#     'period': 'Fall',
#     'term': 'Fall 2019',
#     'internal': 'fall19',
#     'sortkey': '2019_1'}},
#   {'course': 'COS 126',
#    'title': 'Computer Science: An Interdisciplinary Approach',
#    'people': ['R. Sedgewick', 'J. Lumbroso', 'D. Leyzberg'],
#    'hours': 'TTh 10:00-10:50',
#    'room': 'MC50',
#    'term': {'year': 2019,
#     'period': 'Fall',
#     'term': 'Fall 2019',
#     'internal': 'fall19',
#     'sortkey': '2019_1'}},
#   {'course': 'COS 217',
#    'title': 'Introduction to Programming Systems',
#    'people': ['J. Rexford'],
#    'hours': 'TTh 10:00-10:50',
#    'room': 'FC101',
#    'term': {'year': 2019,
#     'period': 'Fall',
#     'term': 'Fall 2019',
#     'internal': 'fall19',
#     'sortkey': '2019_1'}},
#   {'course': 'COS 226',
#    'title': 'Algorithms and Data Structures',
#    'people': ['K. Wayne'],
#    'hours': 'TTh 11:00-12:20',
#    'room': 'FC101',
#    'term': {'year': 2019,
#     'period': 'Fall',
#     'term': 'Fall 2019',
#     'internal': 'fall19',
#     'sortkey': '2019_1'}},
#   {'course': 'COS 231',
#    'title': 'An Integrated, Quantitative Introduction to the Natural Sciences I (See ISC231)',
#    'people': [''],
#    'hours': 'MWF 10:00-10:50',
#    'room': 'IL101',
#    'term': {'year': 2019,
#     'period': 'Fall',
#     'term': 'Fall 2019',
#     'internal': 'fall19',
#     'sortkey': '2019_1'}},
#   {'course': 'COS 232',
#    'title': 'An Integrated, Quantitative Introduction to the Natural Sciences I (See ISC232)',
#    'people': [''],
#    'hours': 'TTh 10:00-10:50',
#    'room': 'IL101',
#    'term': {'year': 2019,
#     'period': 'Fall',
#     'term': 'Fall 2019',
#     'internal': 'fall19',
#     'sortkey': '2019_1'}},
#   {'course': 'COS 306',
#    'title': 'Contemporary Logic Design (See ELE206)',
#    'people': ['S. Malik'],
#    'hours': 'TTh 1:30-2:50',
#    'room': 'FC101',
#    'term': {'year': 2019,
#     'period': 'Fall',
#     'term': 'Fall 2019',
#     'internal': 'fall19',
#     'sortkey': '2019_1'}},
#   {'course': 'COS 314',
#    'title': 'Computer and Electronic Music through Programming, Performance, and Composition (See MUS314)',
#    'people': [''],
#    'hours': 'MW 1:30-2:50',
#    'room': 'WC106',
#    'term': {'year': 2019,
#     'period': 'Fall',
#     'term': 'Fall 2019',
#     'internal': 'fall19',
#     'sortkey': '2019_1'}},
#   {'course': 'COS 316',
#    'title': 'Principles of Computer System Design',
#    'people': ['A. Levy', 'A. Kaplan'],
#    'hours': 'MW 1:30-2:20',
#    'room': 'CS104',
#    'term': {'year': 2019,
#     'period': 'Fall',
#     'term': 'Fall 2019',
#     'internal': 'fall19',
#     'sortkey': '2019_1'}},
#   {'course': 'COS 318',
#    'title': 'Operating Systems',
#    'people': ['J. Singh'],
#    'hours': 'MW 11:00-12:20',
#    'room': 'CS104',
#    'term': {'year': 2019,
#     'period': 'Fall',
#     'term': 'Fall 2019',
#     'internal': 'fall19',
#     'sortkey': '2019_1'}},
#   {'course': 'COS 323',
# ...
#    'people': ['B. Chazelle'],
#    'hours': '',
#    'room': '',
#    'term': {'year': 1996,
#     'period': 'Fall',
#     'term': 'Fall 1996',
#     'internal': 'fall96',
#     'sortkey': '1996_1'}},
#   {'course': 'COS SrC',
#    'title': 'Senior Colloquium',
#    'people': ['E. Felten'],
#    'hours': '',
#    'room': '',
#    'term': {'year': 1996,
#     'period': 'Fall',
#     'term': 'Fall 1996',
#     'internal': 'fall96',
#     'sortkey': '1996_1'}}],
#  'spring96': [{'course': 'COS 126',
#    'title': 'General Computer Science',
#    'people': ['S. Arora', 'A. LaPaugh'],
#    'hours': 'TTh 9:00-7:00',
#    'room': 'CS104',
#    'term': {'year': 1996,
#     'period': 'Spring',
#     'term': 'Spring 1996',
#     'internal': 'spring96',
#     'sortkey': '1996_0'}},
#   {'course': 'COS 128',
#    'title': 'Honors General Computer Science',
#    'people': ['S. Arora', ' A. LaPaugh'],
#    'hours': 'TTh 7:00-7:00',
#    'room': 'CS104',
#    'term': {'year': 1996,
#     'period': 'Spring',
#     'term': 'Spring 1996',
#     'internal': 'spring96',
#     'sortkey': '1996_0'}},
#   {'course': 'COS 217',
#    'title': 'Introduction to Programming Systems',
#    'people': [''],
#    'hours': 'MWF 7:00-7:00',
#    'room': 'CS105',
#    'term': {'year': 1996,
#     'period': 'Spring',
#     'term': 'Spring 1996',
#     'internal': 'spring96',
#     'sortkey': '1996_0'}},
#   {'course': 'COS 226',
#    'title': 'Algorithms and Data Structures',
#    'people': ['R. Sedgewick'],
#    'hours': 'MW 7:00-7:00',
#    'room': 'CS104',
#    'term': {'year': 1996,
#     'period': 'Spring',
#     'term': 'Spring 1996',
#     'internal': 'spring96',
#     'sortkey': '1996_0'}},
#   {'course': 'COS 291',
#    'title': 'Computers, Ethics and Social Responsibility',
#    'people': [''],
#    'hours': 'MW 7:00-7:00',
#    'room': 'CS105',
#    'term': {'year': 1996,
#     'period': 'Spring',
#     'term': 'Spring 1996',
#     'internal': 'spring96',
#     'sortkey': '1996_0'}},
#   {'course': 'COS 306',
#    'title': 'Introduction to Logic Design ELE 206',
#    'people': ['S. Malik'],
#    'hours': 'TTh 7:00-7:00',
#    'room': 'CS104',
#    'term': {'year': 1996,
#     'period': 'Spring',
#     'term': 'Spring 1996',
#     'internal': 'spring96',
#     'sortkey': '1996_0'}},
#   {'course': 'COS 318',
#    'title': 'Operating Systems',
#    'people': ['R. Lipton'],
#    'hours': 'MWF 7:00-7:00',
#    'room': 'CS102',
#    'term': {'year': 1996,
#     'period': 'Spring',
#     'term': 'Spring 1996',
#     'internal': 'spring96',
#     'sortkey': '1996_0'}},
#   {'course': 'COS 333',
#    'title': 'Advanced Programming Techniques',
#    'people': ['L. Huelsbergen'],
#    'hours': 'MW 7:00-7:00',
#    'room': 'CS105',
#    'term': {'year': 1996,
#     'period': 'Spring',
#     'term': 'Spring 1996',
#     'internal': 'spring96',
#     'sortkey': '1996_0'}},
#   {'course': 'COS 398',
#    'title': 'Junior Independent Work',
#    'people': ['A. LaPaugh'],
#    'hours': '',
#    'room': '',
#    'term': {'year': 1996,
#     'period': 'Spring',
#     'term': 'Spring 1996',
#     'internal': 'spring96',
#     'sortkey': '1996_0'}},
#   {'course': 'COS 423',
#    'title': 'Theory of Algorithms',
#    'people': ['A. Yao'],
#    'hours': 'TTh 7:00-7:00',
#    'room': 'CS105',
#    'term': {'year': 1996,
#     'period': 'Spring',
#     'term': 'Spring 1996',
#     'internal': 'spring96',
#     'sortkey': '1996_0'}},
#   {'course': 'COS 441',
#    'title': 'Programming Languages',
#    'people': ['A. Wright'],
#    'hours': 'TTh 7:00-7:00',
#    'room': 'CS102',
#    'term': {'year': 1996,
#     'period': 'Spring',
#     'term': 'Spring 1996',
#     'internal': 'spring96',
#     'sortkey': '1996_0'}},
#   {'course': 'COS 451',
#    'title': 'Computational Geometry',
#    'people': ['B. Chazelle'],
#    'hours': 'MW 7:00-7:00',
#    'room': 'CS302',
#    'term': {'year': 1996,
#     'period': 'Spring',
#     'term': 'Spring 1996',
#     'internal': 'spring96',
#     'sortkey': '1996_0'}},
#   {'course': 'COS 496',
#    'title': 'Simulation of Systems, Real and Imagined',
#    'people': ['P. Cook', '  K. Steiglitz'],
#    'hours': 'TTh 7:00-7:00',
#    'room': 'CS102',
#    'term': {'year': 1996,
#     'period': 'Spring',
#     'term': 'Spring 1996',
#     'internal': 'spring96',
#     'sortkey': '1996_0'}},
#   {'course': 'COS 498',
#    'title': 'Senior Independent Work',
#    'people': ['A. LaPaugh'],
#    'hours': '',
#    'room': '',
#    'term': {'year': 1996,
#     'period': 'Spring',
#     'term': 'Spring 1996',
#     'internal': 'spring96',
#     'sortkey': '1996_0'}},
#   {'course': 'COS 592',
#    'title': 'Seminar in Computer Systems',
#    'people': ['D. Clark', ' E. Felten'],
#    'hours': 'TTh 7:00-7:00',
#    'room': 'CS105',
#    'term': {'year': 1996,
#     'period': 'Spring',
#     'term': 'Spring 1996',
#     'internal': 'spring96',
#     'sortkey': '1996_0'}},
#   {'course': 'COS 598A',
#    'title': 'Adv Topics: Parallel Computer Architecture',
#    'people': ['J. Singh'],
#    'hours': 'TTh 7:00-7:00',
#    'room': 'CS302',
#    'term': {'year': 1996,
#     'period': 'Spring',
#     'term': 'Spring 1996',
#     'internal': 'spring96',
#     'sortkey': '1996_0'}},
#   {'course': 'COS 598B',
#    'title': 'Adv Topics: Human Language Technology',
#    'people': [''],
#    'hours': 'W 1:00-7:00',
#    'room': 'CS301',
#    'term': {'year': 1996,
#     'period': 'Spring',
#     'term': 'Spring 1996',
#     'internal': 'spring96',
#     'sortkey': '1996_0'}},
#   {'course': 'COS ST 2',
#    'title': 'Computer Graphics Rendering',
#    'people': ['D. Dobkin'],
#    'hours': 'M 7:00-7:00',
#    'room': 'CS105',
#    'term': {'year': 1996,
#     'period': 'Spring',
#     'term': 'Spring 1996',
#     'internal': 'spring96',
#     'sortkey': '1996_0'}},
#   {'course': 'COS ST 2',
#    'title': 'Computer Graphics Rendering',
#    'people': ['D. Dobkin'],
#    'hours': 'F 7:00-7:00',
#    'room': 'CS302',
#    'term': {'year': 1996,
#     'period': 'Spring',
#     'term': 'Spring 1996',
#     'internal': 'spring96',
#     'sortkey': '1996_0'}}],
#  'fall95': [{'course': 'COS 111',
#    'title': 'Computers and Computing',
#    'people': ['K. Steiglitz'],
#    'hours': 'MWF 11:00-11:50',
#    'room': 'CS105',
#    'term': {'year': 1995,
#     'period': 'Fall',
#     'term': 'Fall 1995',
#     'internal': 'fall95',
#     'sortkey': '1995_1'}},
#   {'course': 'COS 126',
#    'title': 'General Computer Science',
#    'people': ['B. Chazelle'],
#    'hours': 'TTh 9:00-10:20',
#    'room': 'CS104',
#    'term': {'year': 1995,
#     'period': 'Fall',
#     'term': 'Fall 1995',
#     'internal': 'fall95',
#     'sortkey': '1995_1'}},
#   {'course': 'COS 217',
#    'title': 'Introduction to Programming Systems',
#    'people': ['J. Singh'],
#    'hours': 'MWF 9:00-9:50',
#    'room': 'CS102',
#    'term': {'year': 1995,
#     'period': 'Fall',
#     'term': 'Fall 1995',
#     'internal': 'fall95',
#     'sortkey': '1995_1'}},
#   {'course': 'COS 302',
#    'title': 'Intro. to Artificial Intelligence',
#    'people': [''],
#    'hours': 'TTh 3:00-4:20',
#    'room': 'CS105',
#    'term': {'year': 1995,
#     'period': 'Fall',
#     'term': 'Fall 1995',
#     'internal': 'fall95',
#     'sortkey': '1995_1'}},
#   {'course': 'COS 320',
#    'title': 'Compiling Techniques',
#    'people': ['A. Appel'],
#    'hours': 'MWF 11:00-11:50',
#    'room': 'CS102',
#    'term': {'year': 1995,
#     'period': 'Fall',
#     'term': 'Fall 1995',
#     'internal': 'fall95',
#     'sortkey': '1995_1'}},
#   {'course': 'COS 341',
#    'title': 'Discrete Mathematics',
#    'people': ['A. Yao'],
#    'hours': 'TTh 10:30-11:50',
#    'room': 'CS105',
#    'term': {'year': 1995,
#     'period': 'Fall',
#     'term': 'Fall 1995',
#     'internal': 'fall95',
#     'sortkey': '1995_1'}},
#   {'course': 'COS 397',
#    'title': 'Junior Independent Work',
#    'people': ['A. LaPaugh'],
#    'hours': '',
#    'room': '',
#    'term': {'year': 1995,
#     'period': 'Fall',
#     'term': 'Fall 1995',
#     'internal': 'fall95',
#     'sortkey': '1995_1'}},
#   {'course': 'COS 426',
#    'title': 'Computer Graphics',
#    'people': ['D. Dobkin'],
#    'hours': 'MW 1:00-2:20',
#    'room': 'CS105',
#    'term': {'year': 1995,
#     'period': 'Fall',
#     'term': 'Fall 1995',
#     'internal': 'fall95',
#     'sortkey': '1995_1'}},
#   {'course': 'COS 461',
#    'title': 'Distributed Computing',
#    'people': ['E. Felten'],
#    'hours': 'TTh 9:00-10:20',
#    'room': 'CS102',
#    'term': {'year': 1995,
#     'period': 'Fall',
#     'term': 'Fall 1995',
#     'internal': 'fall95',
#     'sortkey': '1995_1'}},
#   {'course': 'COS 471',
#    'title': 'Computer Architecture and Organization',
#    'people': ['D. Clark'],
#    'hours': 'TTh 10:30-11:50',
#    'room': 'CS102',
#    'term': {'year': 1995,
#     'period': 'Fall',
#     'term': 'Fall 1995',
#     'internal': 'fall95',
#     'sortkey': '1995_1'}},
#   {'course': 'COS 497',
#    'title': 'Senior Independent Work',
#    'people': ['A. LaPaugh'],
#    'hours': '',
#    'room': '',
#    'term': {'year': 1995,
#     'period': 'Fall',
#     'term': 'Fall 1995',
#     'internal': 'fall95',
#     'sortkey': '1995_1'}},
#   {'course': 'COS 591',
#    'title': 'Seminar in Computer Systems',
#    'people': ['D. Clark', ' K. Li', ' E. Felten'],
#    'hours': 'M 3:00-5:00',
#    'room': 'CS302',
#    'term': {'year': 1995,
#     'period': 'Fall',
#     'term': 'Fall 1995',
#     'internal': 'fall95',
#     'sortkey': '1995_1'}},
#   {'course': 'COS 593',
#    'title': 'Adv. Top. Theory of Algos: Algorithm Analysis',
#    'people': ['R. Sedgewick'],
#    'hours': 'TTh 2:30-3:50',
#    'room': 'CS301',
#    'term': {'year': 1995,
#     'period': 'Fall',
#     'term': 'Fall 1995',
#     'internal': 'fall95',
#     'sortkey': '1995_1'}},
#   {'course': 'COS 595',
#    'title': 'Ad. Top. Soft. Sys.: Advanced Compilers',
#    'people': [''],
#    'hours': 'TTh 1:00-2:20',
#    'room': 'CS302',
#    'term': {'year': 1995,
#     'period': 'Fall',
#     'term': 'Fall 1995',
#     'internal': 'fall95',
#     'sortkey': '1995_1'}},
#   {'course': 'COS 597A',
#    'title': 'Adv. Topics in CS: DNA Based Computers',
#    'people': ['R. Lipton'],
#    'hours': 'TTh 1:00-2:20',
#    'room': 'CS301',
#    'term': {'year': 1995,
#     'period': 'Fall',
#     'term': 'Fall 1995',
#     'internal': 'fall95',
#     'sortkey': '1995_1'}},
#   {'course': 'COS 597B',
#    'title': 'Adv. Topics in CS: Randomized Algorithms',
#    'people': ['S. Arora'],
#    'hours': 'WF 10:30-7:00',
#    'room': 'CS302',
#    'term': {'year': 1995,
#     'period': 'Fall',
#     'term': 'Fall 1995',
#     'internal': 'fall95',
#     'sortkey': '1995_1'}}],
#  'spring95': [{'course': 'COS 126',
#    'title': 'General Computer Science',
#    'people': ['A. LaPaugh'],
#    'hours': 'TTh 9:00-10:20',
#    'room': 'CS104',
#    'term': {'year': 1995,
#     'period': 'Spring',
#     'term': 'Spring 1995',
#     'internal': 'spring95',
#     'sortkey': '1995_0'}},
#   {'course': 'COS 206',
#    'title': 'Introduction to Logic Design (ELE 206)',
#    'people': ['S. Malik'],
#    'hours': 'TTh 1:30-2:50',
#    'room': 'CS',
#    'term': {'year': 1995,
#     'period': 'Spring',
#     'term': 'Spring 1995',
#     'internal': 'spring95',
#     'sortkey': '1995_0'}},
#   {'course': 'COS 217',
#    'title': 'Introduction to Programming Systems',
#    'people': ['K. Li'],
#    'hours': 'MWF 10:00-7:00',
#    'room': 'CS102',
#    'term': {'year': 1995,
#     'period': 'Spring',
#     'term': 'Spring 1995',
#     'internal': 'spring95',
#     'sortkey': '1995_0'}},
#   {'course': 'COS 226',
#    'title': 'Algorithms and Data Structures',
#    'people': ['E. Felten'],
#    'hours': 'MW 11:00-7:00',
#    'room': 'CS104',
#    'term': {'year': 1995,
#     'period': 'Spring',
#     'term': 'Spring 1995',
#     'internal': 'spring95',
#     'sortkey': '1995_0'}},
#   {'course': 'COS 318',
#    'title': 'Operating Systems',
#    'people': ['R. Lipton'],
#    'hours': 'TTh 3:00-4:20',
#    'room': 'CS102',
#    'term': {'year': 1995,
#     'period': 'Spring',
#     'term': 'Spring 1995',
#     'internal': 'spring95',
#     'sortkey': '1995_0'}},
#   {'course': 'COS 325',
#    'title': 'Transforming Reality by Computer (MUS 325)',
#    'people': ['K. Steiglitz', ' P. Lansky'],
#    'hours': 'TTh 1:30-2:50',
#    'room': 'CS105',
#    'term': {'year': 1995,
#     'period': 'Spring',
#     'term': 'Spring 1995',
#     'internal': 'spring95',
#     'sortkey': '1995_0'}},
#   {'course': 'COS 333',
#    'title': 'Advanced Programming Techniques',
#    'people': ['G. Jacobson'],
#    'hours': 'MW 1:30-2:50',
#    'room': 'CS105',
#    'term': {'year': 1995,
#     'period': 'Spring',
#     'term': 'Spring 1995',
#     'internal': 'spring95',
#     'sortkey': '1995_0'}},
#   {'course': 'COS 398',
#    'title': 'Junior Independent Work',
#    'people': ['A. LaPaugh'],
#    'hours': '',
#    'room': 'CS402',
#    'term': {'year': 1995,
#     'period': 'Spring',
#     'term': 'Spring 1995',
#     'internal': 'spring95',
#     'sortkey': '1995_0'}},
#   {'course': 'COS 423',
#    'title': 'Theory of Algorithms',
#    'people': ['R. Tarjan'],
#    'hours': 'MWF 10:00-7:00',
#    'room': 'CS102',
#    'term': {'year': 1995,
#     'period': 'Spring',
#     'term': 'Spring 1995',
#     'internal': 'spring95',
#     'sortkey': '1995_0'}},
#   {'course': 'COS 441',
#    'title': 'Programming Languages',
#    'people': [''],
#    'hours': 'TTh 9:00-10:20',
#    'room': 'CS301',
#    'term': {'year': 1995,
#     'period': 'Spring',
#     'term': 'Spring 1995',
#     'internal': 'spring95',
#     'sortkey': '1995_0'}},
#   {'course': 'COS 451',
#    'title': 'Computational Geometry',
#    'people': ['B. Chazelle'],
#    'hours': 'TTh 3:00-4:20',
#    'room': 'CS302',
#    'term': {'year': 1995,
#     'period': 'Spring',
#     'term': 'Spring 1995',
#     'internal': 'spring95',
#     'sortkey': '1995_0'}},
#   {'course': 'COS 471',
#    'title': 'Computer Architecture and Organization',
#    'people': ['D. Clark'],
#    'hours': 'TTh 10:30-11:50',
#    'room': 'CS301',
#    'term': {'year': 1995,
#     'period': 'Spring',
#     'term': 'Spring 1995',
#     'internal': 'spring95',
#     'sortkey': '1995_0'}},
#   {'course': 'COS 498',
#    'title': 'Senior Independent Work',
#    'people': ['A. LaPaugh'],
#    'hours': '',
#    'room': 'CS402',
#    'term': {'year': 1995,
#     'period': 'Spring',
#     'term': 'Spring 1995',
#     'internal': 'spring95',
#     'sortkey': '1995_0'}},
#   {'course': 'COS 510',
#    'title': 'Programming Languages',
#    'people': ['A. Appel'],
#    'hours': 'MW 1:30-2:50',
#    'room': 'CS301',
#    'term': {'year': 1995,
#     'period': 'Spring',
#     'term': 'Spring 1995',
#     'internal': 'spring95',
#     'sortkey': '1995_0'}},
#   {'course': 'COS 592',
#    'title': 'Seminar in Computer Systems',
#    'people': ['D. Clark', ' E. Felten', ' K. Li'],
#    'hours': 'M 3:00-5:00',
#    'room': 'CS302',
#    'term': {'year': 1995,
#     'period': 'Spring',
#     'term': 'Spring 1995',
#     'internal': 'spring95',
#     'sortkey': '1995_0'}},
#   {'course': 'COS 596',
#    'title': 'Adv. Topics in Software Systems: Systems Programming Workshop',
#    'people': [''],
#    'hours': 'MWF 11:00-7:00',
#    'room': 'CS302',
#    'term': {'year': 1995,
#     'period': 'Spring',
#     'term': 'Spring 1995',
#     'internal': 'spring95',
#     'sortkey': '1995_0'}},
#   {'course': 'COS 598A',
#    'title': 'Adv. Topics in CS: Interdisciplinary Algorithms',
#    'people': ['A. Yao'],
#    'hours': 'TTh 1:30-2:50',
#    'room': 'CS302',
#    'term': {'year': 1995,
#     'period': 'Spring',
#     'term': 'Spring 1995',
#     'internal': 'spring95',
#     'sortkey': '1995_0'}},
#   {'course': 'COS 598B',
#    'title': 'Adv. Topics in CS: Randomness in Complexity Theory',
#    'people': ['S. Arora'],
#    'hours': 'TTh 10:30-11:50',
#    'room': 'CS302',
#    'term': {'year': 1995,
#     'period': 'Spring',
#     'term': 'Spring 1995',
#     'internal': 'spring95',
#     'sortkey': '1995_0'}},
#   {'course': 'COS 598C',
#    'title': 'Adv. Topics in CS: Parallel Computer Architecture',
#    'people': ['J. Singh'],
#    'hours': 'TTh 1:00-2:20',
#    'room': 'CS102',
#    'term': {'year': 1995,
#     'period': 'Spring',
#     'term': 'Spring 1995',
#     'internal': 'spring95',
#     'sortkey': '1995_0'}},
#   {'course': 'COS 598D',
#    'title': 'Adv. Topics in CS: Language Recognition',
#    'people': [''],
#    'hours': 'F 1:00-4:00',
#    'room': 'CS302',
#    'term': {'year': 1995,
#     'period': 'Spring',
#     'term': 'Spring 1995',
#     'internal': 'spring95',
#     'sortkey': '1995_0'}},
#   {'course': 'COS ST-1',
#    'title': 'Applied Cryptography',
#    'people': ['E. Felten', 'R. Lipton'],
#    'hours': 'W 7:00-10:00',
#    'room': 'RH3',
#    'term': {'year': 1995,
#     'period': 'Spring',
#     'term': 'Spring 1995',
#     'internal': 'spring95',
#     'sortkey': '1995_0'}}]}
